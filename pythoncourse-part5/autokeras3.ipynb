# %% [markdown]
# # 6. Object detection

# %% [markdown]
# ### 6.2. Using Auto-Keras’ pre-trained models for object detection

# %%
# Single Short Multibox Detector
# pre-trained on the VOC data set: http://host.robots.ox.ac.uk/pascal/VOC/

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from autokeras_pretrained.object_detector import ObjectDetector
detector = ObjectDetector()

#img_name = 'catdogsquirrel'
img_ext = '.png'
img_name = 'C:\DEV\catdogs.png'
img_result = 'C:/DEV/catdogs_prediction.png'
results = detector.predict(img_name)
print(results)

results_folder = 'results/'
results = detector.predict(img_name, 
                           output_file_path=results_folder)
img = mpimg.imread(img_result)
plot = plt.imshow(img)
# Out:
# Finished loading model!
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# [{'left': 388, 'top': 428, 'width': 267, 'height': 445, 'category': 'cat', 'confidence': 0.8429293036460876}, {'left': 41, 'top': 214, 'width': 391, 'height': 697, 'category': 'dog', 'confidence': 0.8510644435882568}, {'left': 1212, 'top': 239, 'width': 328, 'height': 684, 'category': 'dog', 'confidence': 0.7694870829582214}]
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)

# %%
# Single Short Multibox Detector
# pre-trained on the VOC data set: http://host.robots.ox.ac.uk/pascal/VOC/

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from autokeras_pretrained.object_detector import ObjectDetector
detector = ObjectDetector()

#img_name = 'catdogsquirrel'
img_ext = '.png'
img_name = 'C:\DEV\carpeople.jpg'
img_result = 'C:/DEV/carpeople_prediction.jpg'
results = detector.predict(img_name)
print(results)

results_folder = 'results/'
results = detector.predict(img_name, 
                           output_file_path=results_folder)
img = mpimg.imread(img_result)
plot = plt.imshow(img)
# Out:
# Finished loading model!
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# [{'left': 102, 'top': 316, 'width': 1054, 'height': 623, 'category': 'car', 'confidence': 0.9823219180107117}, {'left': 704, 'top': 277, 'width': 314, 'height': 636, 'category': 'person', 'confidence': 0.7232693433761597}]
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)

# %% [markdown]
# ### 6.3. Building our own data set for use with the pre-trained model

# %%
# based on https://dev.to/petercour/image-scraping-with-python-330a

import re
import requests

def download_baidu(keyword, max_results=20): 
    url = 'https://image.baidu.com/search/flip?tn=baiduimage&ie=utf-8&word='+keyword+'&ct=201326592&v=flip'
    result = requests.get(url)
    html = result.text
    pic_url = re.findall('"objURL":"(.*?)",',html,re.S)

    for i, each in enumerate(pic_url):
        if i >= max_results:
            break
        print(i, '/', len(pic_url))
        try:
            pic = requests.get(each, timeout=10)
        except Exception:
            print('exception')
            continue

        string = 'C:\DEV\images\_'+keyword+'_'+str(i) + '.jpg'
        fp = open(string,'wb')
        fp.write(pic.content)
        fp.close()


download_baidu('cars+people')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-10f5727e3194> in <module>
#      26
#      27
# ---> 28 download_baidu('cars+people')
#
# <ipython-input-10-10f5727e3194> in download_baidu(keyword, max_results)
#       6 def download_baidu(keyword, max_results=20):
#       7     url = 'https://image.baidu.com/search/flip?tn=baiduimage&ie=utf-8&word='+keyword+'&ct=201326592&v=flip'
# ----> 8     result = requests.get(url)
#       9     html = result.text
#      10     pic_url = re.findall('"objURL":"(.*?)",',html,re.S)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     558         """
#     559         if self.chunked and self.supports_chunked_reads():
# --> 560             for line in self.read_chunked(amt, decode_content=decode_content):
#     561                 yield line
#     562         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     750
#     751             while True:
# --> 752                 self._update_chunk_length()
#     753                 if self.chunk_left == 0:
#     754                     break
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     680         if self.chunk_left is not None:
#     681             return
# --> 682         line = self._fp.fp.readline()
#     683         line = line.split(b";", 1)[0]
#     684         try:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from autokeras_pretrained.object_detector import ObjectDetector
import os
import traceback

results_folder = 'C:/DEV/results/'

detector = ObjectDetector()

directory = os.fsencode('C:/DEV/images/')
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    directory = os.fsdecode(directory)
    if not filename.endswith('.jpg'):
        continue
    print(filename)
    try:
        results = detector.predict(directory+filename, 
                                   output_file_path=results_folder)
    except Exception:
        print('skipping', directory+filename)
        #print('skipping', filename)
        print(Exception)
        traceback.print_exc()
        continue
    filename_parts = filename.split('.')
    #to_read = results_folder + filename_parts[0] + '_prediction.' + filename_parts[1]
    to_read = 'C:/DEV/images/_cars+people_1.jpg'
    img = mpimg.imread(to_read)
    plot = plt.imshow(img)
    plt.show()
# Out:
# Finished loading model!
# _cars+people_1.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_10.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_11.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_12.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_13.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_14.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_15.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_16.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_17.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_18.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_19.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_3.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_4.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_5.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_6.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_7.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_8.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)
# _cars+people_9.jpg
# ..\torch\csrc\autograd\python_function.cpp:622: UserWarning: Legacy autograd function with non-static forward method is deprecated and will be removed in 1.3. Please use new-style autograd function with static forward method. (Example: https://pytorch.org/docs/stable/autograd.html#torch.autograd.Function)

# %%
print(results)
# Out:
# [{'left': 388, 'top': 428, 'width': 267, 'height': 445, 'category': 'cat', 'confidence': 0.8429293036460876}, {'left': 41, 'top': 214, 'width': 391, 'height': 697, 'category': 'dog', 'confidence': 0.8510644435882568}, {'left': 1212, 'top': 239, 'width': 328, 'height': 684, 'category': 'dog', 'confidence': 0.7694870829582214}]

# %%
directory = os.fsencode('C:/DEV/images')
for file in os.listdir(directory):
    print(filename)
# Out:
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
# _cars+people_9.jpg
